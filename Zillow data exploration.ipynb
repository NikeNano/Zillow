# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("Imports done")
# Out:
# Imports done

# %%
# This input paths are 
path_data = '/Users/Niklas/Documents/Zillow_data/properties_2016.csv'
path_subSample = '/Users/Niklas/Documents/Zillow_data/sample_submission.csv'
path_train = '/Users/Niklas/Documents/Zillow_data/train_2016_v2.csv'

paths = [path_data, path_subSample, path_train]

from pathlib import Path

Paths = 0
for path in paths:
    my_file = Path(path)
    if my_file.is_file():
        Paths+=1
if Paths ==len(paths):
    print("All data is imported")
# Out:
# All data is imported

# %%
dataframe=pd.read_csv(path_data)
print("imported")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# imported

# %%
dataframe.head(n=5)
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# ...

# %%
a=dataframe.describe(include='all')
print(a)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/numpy/lib/function_base.py:4269: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#             parcelid  airconditioningtypeid  architecturalstyletypeid  \
# count   2.985217e+06          811519.000000               6061.000000
# unique           NaN                    NaN                       NaN
# top              NaN                    NaN                       NaN
# freq             NaN                    NaN                       NaN
# mean    1.332586e+07               1.931166                  7.202607
# std     7.909966e+06               3.148587                  2.436290
# min     1.071172e+07               1.000000                  2.000000
# 25%     1.164371e+07                    NaN                       NaN
# 50%     1.254509e+07                    NaN                       NaN
# 75%     1.409712e+07                    NaN                       NaN
# ...

# %%
columns=list(a)
a=a.loc["count",:]

# %%
a.plot(kind='bar')
plt.show()
Count_Row=dataframe.shape[0] #gives number of row count
Count_Col=dataframe.shape[1] #gives number of col count
print("The number of observations is {}".format(Count_Row))
print("The number of variables is {}" . format(Count_Col))
# Out:
# The number of observations is 2985217
# The number of variables is 58

# %%
drop=[]
for ind, val in a.iteritems():
    print(ind,val)
    if val<2900000:
        drop.append(ind)
print(len(drop))
dataframe_reduced = dataframe.drop(drop, 1)
print("done")
dataframe_reduced.head(n=10)
# Out:
# parcelid 2985217.0
# airconditioningtypeid 811519.0
# architecturalstyletypeid 6061.0
# basementsqft 1628.0
# bathroomcnt 2973755.0
# bedroomcnt 2973767.0
# buildingclasstypeid 12629.0
# buildingqualitytypeid 1938488.0
# calculatedbathnbr 2856305.0
# decktypeid 17096.0
# finishedfloor1squarefeet 202717.0
# calculatedfinishedsquarefeet 2929652.0
# finishedsquarefeet12 2709184.0
# finishedsquarefeet13 7672.0
# finishedsquarefeet15 190798.0
# finishedsquarefeet50 202717.0
# finishedsquarefeet6 22001.0
# fips 2973780.0
# fireplacecnt 312637.0
# fullbathcnt 2856305.0
# garagecarcnt 883267.0
# garagetotalsqft 883267.0
# hashottuborspa 69014
# heatingorsystemtypeid 1806401.0
# latitude 2973780.0
# longitude 2973780.0
# lotsizesquarefeet 2709118.0
# poolcnt 517534.0
# poolsizesum 27960.0
# pooltypeid10 36939.0
# pooltypeid2 32075.0
# pooltypeid7 485459.0
# propertycountylandusecode 2972940
# propertylandusetypeid 2973780.0
# propertyzoningdesc 1978629
# rawcensustractandblock 2973780.0
# ...

# %%
dataframe_reduced.isnull().sum()
# Out:
# parcelid                            0
# bathroomcnt                     11462
# bedroomcnt                      11450
# calculatedfinishedsquarefeet    55565
# fips                            11437
# latitude                        11437
# longitude                       11437
# propertycountylandusecode       12277
# propertylandusetypeid           11437
# rawcensustractandblock          11437
# regionidcity                    62845
# regionidcounty                  11437
# regionidzip                     13980
# roomcnt                         11475
# yearbuilt                       59928
# structuretaxvaluedollarcnt      54982
# taxvaluedollarcnt               42550
# assessmentyear                  11439
# landtaxvaluedollarcnt           67733
# taxamount                       31250
# censustractandblock             75126
# dtype: int64

# %%
dataframe_reduced.fillnan
